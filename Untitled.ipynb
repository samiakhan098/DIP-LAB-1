# %%
#Reading tiff image
import rasterio
from rasterio.plot import show
from PIL import Image
img = Image.open("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif")
show(img)
pixels = img.load()

# %%
#Metadata of the image
import rasterio
with rasterio.open("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif") as dataset:
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
# Out:
# Image Size (Width x Height): 5600 x 4700
# Number of Bands: 1

# %%
dataset.count
dataset.width
dataset.height
# Out:
# 4700

# %%
import numpy as np
from PIL import Image
img = Image.open("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif")
img_array = np.array(img)
mean = np.mean(img_array)
std_dev = np.std(img_array)
min = np.min(img_array)
max = np.max(img_array)
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)
# Out:
# Mean: 4180.520511018237
# Standard Deviation: 2508.197081682334
# Min: 0
# Max: 65535

# %%
#Size reduction
import matplotlib.pyplot as plt
import cv2
import numpy as np

 
try:
    img = cv2.imread("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif") 
    (height, width) = img.shape[:2]    
    res = cv2.resize(img, (int(width / 8), int(height / 8)), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite('result.tiff', res)
    plt.imshow(res)
 
except IOError:
    print('Error while reading files !!!')

# %%
#Rotating the image
try:
    img = cv2.imread("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif")
    (rows, cols) = img.shape[:2]
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 40, 1)
    res1 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res1)
    plt.imshow(res1)
except IOError:
    print('Error while reading files !!!')

# %%
# Shifting image shift by (200, 200).
M = np.float32([[1, 0, 200], [0, 1, 200]])
try:
    img = cv2.imread("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif")
    res2 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res2)
    plt.imshow(res2)
except IOError:
    print('Error while reading files !!!')

# %%
#Canny edge reduction
try:
    img = cv2.imread("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif")
    edges = cv2.Canny(img, 150, 100)
    cv2.imwrite('result.tiff', edges)
    plt.imshow(edges)
except IOError:
    print('Error while reading files !!!')

# %%
#Converting into RGB
import cv2
import matplotlib.pyplot as plt
try:
    img2 = cv2.imread("C:\\Users\\abc\\Desktop\\Compressed\\Samia\\HH-ALPSRP247640530-H2.2_UA.tif")
    img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    plt.imshow(img2_rgb)
except IOError:
    print('Error while reading files !!!')
